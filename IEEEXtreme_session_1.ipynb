# %% [markdown]
# # **IEEEXtreme 14.0**
# [Website](https://https://ieeextreme.org/) ![LogoXtreme14 Color.png](data:image/png;base64,...)

# %% [markdown]
# #Quick Warm-up session

# %% [markdown]
# ##Problem 1 Diagonal Difference
# Given a square matrix, calculate the absolute difference between the sums of its diagonals.
#
# For example, the square matrix  is shown below:
#
# 1 2 3
# 4 5 6
# 9 8 9
# The left-to-right diagonal = . The right to left diagonal = . Their absolute difference is .
#
# Function description
#
# Complete the  function in the editor below.
#
# diagonalDifference takes the following parameter:
#
# int arr[n][m]: an array of integers
# Return
#
# int: the absolute diagonal differenc

# %%
import math
Mat=[[1, 2, 3],
     [4 ,5, 6],
     [9, 8, 9 ]]

# %%
def diagonalDifference(arr):
    s1=0
    s2=0 
    j=len(arr)-1
    for i in range(len(arr)):
        s1=(arr[i][i])+s1
        s2=(arr[i][j])+s2
        j=j-1
    return abs(s1-s2)

# %%
diagonalDifference(Mat)
# Out:
# 2

# %%
arr=[[11, 2 ,4],
     [4 ,5, 6],
     [10, 8 ,-12]]

# %%
diagonalDifference(arr)
# Out:
# 15

# %% [markdown]
# ## Problem 2 Staircase
# This is a staircase of size n=4 :
#
#    #
#   ##
#  ###
# ####
#
# Its base and height are both equal to . It is drawn using # symbols and spaces. The last line is not preceded by any spaces.
#
# Write a program that prints a staircase of size .
#
# Function Description
#
# Complete the staircase function in the editor below.
#
# staircase has the following parameter(s):
#
# *int n: an integer
# Print
#
# Print a staircase as described above.
#
# Input Format
#
# A single integer, , denoting the size of the staircase.

# %%
# Creates a list containing 5 lists, each of 8 items, all set to 0

def stair():
  from pprint import pprint
  n = int(input())
  w, h = n, n
  Matrix = [['' for x in range(w)] for y in range(h)] 
  j=n-1
  for i in  reversed(range(n)):
    for j in  reversed(range(n)):
      if j<=i:
        Matrix[i][j]='#'
  pprint(Matrix)

# %%
stair()
# Out:
# 5
# [['#', '', '', '', ''],
#  ['#', '#', '', '', ''],
#  ['#', '#', '#', '', ''],
#  ['#', '#', '#', '#', ''],
#  ['#', '#', '#', '#', '#']]

# %%
def stair2():
  n = int(input())
  for i in range(1,n+1):
      number="#"*i
      print(" "*(n-i)+number)

# %%
stair2()
# Out:
# 2
#  #
# ##

# %% [markdown]
# ## Problem 3 Time Conversion
# Given a time in 12-hour AM/PM format, convert it to military (24-hour) time.
#
# Note : Midnight is 12:00:00 AM on a 12-hour clock and 00:00:00 on a 24-hour clock. Noon is 12:00:00 PM on 12-hour clock and 12:00:00 on 24-hour clock.

# %%
# Function to convert the date format 
def convert24(str1): 
      
    # Checking if last two elements of time 
    # is AM and first two elements are 12 
    if str1[-2:] == "AM" and str1[:2] == "12": 
        return "00" + str1[2:-2] 
          
    # remove the AM     
    elif str1[-2:] == "AM": 
        return str1[:-2] 
      
    # Checking if last two elements of time 
    # is PM and first two elements are 12    
    elif str1[-2:] == "PM" and str1[:2] == "12": 
        return str1[:-2] 
          
    else: 
          
        # add 12 to hours and remove PM 
        return str(int(str1[:2]) + 12) + str1[2:8] 
  
# Driver Code         
print(convert24("08:05:45 PM"))
# Out:
# 20:05:45

# %% [markdown]
# ##Problem 4 Change Problem
# Convert some amount of money into given denominations, using the smallest
# possible number of coins.
# Input: An integer money and an array of d denominations c =
# (c1; c2; : ... ; cd), in decreasing order of value (c1 > c2 > ... > cd).
# Output: A list of d integers i1; i2; ...; id such that c1 * i1 + c2 * i2 +
# ... + cd * id = money; and i1 + i2 + ... + id is as small as possible.

# %%
def convert(amount):
  money = [25,10,5,1]
  i=0
  while(amount>0 and i<len(money) ):
        m=money[i]
        if amount -m >=0:
          amount = amount-m
          print(str(m))
        else :
          i=i+1  
  print("donne")

# %%
convert(214)
# Out:
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 10
# 1
# 1
# 1
# 1
# donne

# %%
def change(money,c):
  cur=[]
  num=[]
  r=money
  for k in range(0,len(c)):
    i=(r // c[k])
    r=r-(c[k]*i)
    cur.append(c[k])
    num.append(i)
  return cur,num

# %%
change(214,[25,10,5,1])
# Out:
# ([25, 10, 5, 1], [8, 1, 0, 4])

# %% [markdown]
# ###PLz Note

# %%
22//5
# Out:
# 4

# %%
22/5
# Out:
# 4.4

# %% [markdown]
# #TO DO
# consider every possible
# combination of coins with denominations c1; c2; : : : ; cd that adds to money,
# and return the combination with the fewest.
# Exemple 40
# c =[25,20,10,5,1]
# return : 20 20

# %%
def change(money,c):
#WRITE YOUR CODE
# Out:
#   File "<ipython-input-22-48369ac20af9>", line 1
#     def change(money,c):
#                         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# After you designed an algorithm, two important questions
#
# *   “Does it work correctly?”
# *   “How much time will it take?”

# %% [markdown]
# **#WHAT NEXT ?**
#
# ---
